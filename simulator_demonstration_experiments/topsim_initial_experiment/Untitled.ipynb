# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import CenteredNorm, LogNorm, TwoSlopeNorm, Normalize
from matplotlib import cm
import pandas as pd 
import seaborn as sns

results = {'No data': [13317, 12366, 11942],
           'Data transfer only': [30517, 31901, 11955],
          'Task and transfer data': [52449,50460,24593]}

fig, ax = plt.subplots(figsize=(10,8)) 
# x=[
#     'No heuristic', 'FCFS', 'HEFT'
# ]
x = np.arange(3)
i = 0 
width = 0.25
for attr in results:
    rects= ax.bar(x + (i*width), results[attr], width, label=attr)
#     ax.bar_label(rects, padding=3)
    i +=1
ax.set_xticks(x+width, ['No heuristic', 'FCFS', 'HEFT'])
ax.legend()
